# %%
from src.utils import get_toy_data

import numpy as np
import matplotlib.pyplot as plt

# %%
# Create toy dataset with 2 features. 
X, y = get_toy_data()

# %%
# Plot the data 
plt.scatter(X[:, 0], X[:, 1], c=y)
plt.colorbar()
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Toy dataset')
# Out:
# Text(0.5, 1.0, 'Toy dataset')

# %%
plt.scatter(X[:, 0], y)

# %%
plt.scatter(X[:, 1], y)
